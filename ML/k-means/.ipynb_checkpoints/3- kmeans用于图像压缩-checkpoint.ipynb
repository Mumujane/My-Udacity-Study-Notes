# %% [markdown]
# # 3- kmeans for image compression

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # load image as ndarray

# %%
from skimage import io

# cast to float, you need to do this otherwise the color would be weird after clustring
pic = io.imread('./data/bird_small.png') / 255
io.imshow(pic)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
pic.shape
# Out:
# (128, 128, 3)

# %%
# serialize data 
data = pic.reshape(128*128, 3)

# %% [markdown]
# # let's do k-mean
# my version will take more than 10 mins... ok. I know why I shouldn't implement my own ML library.
#
# In the future I will only implement ML algorithm for the sake of learning it XD

# %%
def k_means(data, k, epoch=100, n_init=10):
    """
        do multiple random init and pick the best one to return
    Args:
        data (pd.DataFrame)
    Returns:
        (C, centroids, least_cost)
    """
    
    tries = np.array([_k_means_iter(data, k, epoch) for _ in range(n_init)])
    
    least_cost_idx = np.argmin(tries[:, -1])
    
    return tries[least_cost_idx]

# %%
# support fn --------
def combine_data_C(data, C):
    data_with_c = data.copy()
    data_with_c['C'] = C
    return data_with_c

# k-means fn -------
def random_init(data, k):
    """
        choose k sample from data set as init centroids
    Args:
        data: DataFrame
        k: int
    Returns:
        k samples: ndarray
    """
    return data.sample(k).as_matrix()

def _find_your_cluster(x, centroids):
    """
        find the right cluster for x with respect to shortest distance
    Args:
        x: ndarray(n, ) -> n features
        centroids: ndarray(k, n)
    Returns:
        k: int
    """
    distances = np.apply_along_axis(func1d=np.linalg.norm,
                                   axis =1,
                                   arr = centroids-x)
    
    return np.argmin(distances)

def assign_cluster(data, centroids):
    """
        assign cluster for each node in data
    Return C ndarray
    """
    return np.apply_along_axis(lambda x: _find_your_cluster(x, centroids),
                              axis = 1,
                               arr=data.as_matrix()
                              )

def new_centroids(data, C):
    data_with_c = combine_data_C(data, C)
    return data_with_c.groupby('C', as_index=False).mean().sort_values(by='C').drop('C', axis=1).as_matrix()


def cost(data, centroids, C):
    m = data.shape[0]
    expand_C_wiht_centroids = centroids[C]
    distance = np.apply_along_axis(func1d=np.linalg.norm,
                                  axis=1,
                                  arr=data.as_matrix() - expand_C_wiht_centroids)
    return distance.sum()/m

def _k_means_iter(data, k, epoch=100, tol=0.0001):
    """
        one shot k-means with early break
    """
    centroids = random_init(data, k)
    cost_progess = []
    
    for i in range(epoch):
        print('running epoch {}'.format(i))
        
        C = assign_cluster(data, centroids)
        centroids = new_centroids(data, C)
        cost_progess.append(cost(data, centroids, C))
        
        if len(cost_progess) > 1:
            if(np.abs(cost_progess[-1] - cost_progess[-2])) / cost_progess[-1] < tol:
                break
    
    return C, centroids, cost_progess[-1]

# %%
c, centroids, cost = k_means(pd.DataFrame(data), 16, epoch=10, n_init=3)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# running epoch 0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:54: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# running epoch 1
# running epoch 2
# running epoch 3
# running epoch 4
# running epoch 5
# running epoch 6
# running epoch 7
# running epoch 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-433d038f9656> in <module>()
# ----> 1 c, centroids, cost = k_means(pd.DataFrame(data), 16, epoch=10, n_init=3)
#
# <ipython-input-7-a4ab1b15570b> in k_means(data, k, epoch, n_init)
#       8     """
#       9
# ---> 10     tries = np.array([_k_means_iter(data, k, epoch) for _ in range(n_init)])
#      11
#      12     least_cost_idx = np.argmin(tries[:, -1])
#
# <ipython-input-7-a4ab1b15570b> in <listcomp>(.0)
#       8     """
#       9
# ---> 10     tries = np.array([_k_means_iter(data, k, epoch) for _ in range(n_init)])
#      11
#      12     least_cost_idx = np.argmin(tries[:, -1])
#
# <ipython-input-11-a96e86fac751> in _k_means_iter(data, k, epoch, tol)
#      65         print('running epoch {}'.format(i))
#      66
# ---> 67         C = assign_cluster(data, centroids)
#      68         centroids = new_centroids(data, C)
#      69         cost_progess.append(cost(data, centroids, C))
#
# <ipython-input-11-a96e86fac751> in assign_cluster(data, centroids)
#      39     return np.apply_along_axis(lambda x: _find_your_cluster(x, centroids),
#      40                               axis = 1,
# ---> 41                                arr=data.as_matrix()
#      42                               )
#      43
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     153     buff[ind0] = res
#     154     for ind in inds:
# --> 155         buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     156
#     157     if not isinstance(res, matrix):
#
# <ipython-input-11-a96e86fac751> in <lambda>(x)
#      37     Return C ndarray
#      38     """
# ---> 39     return np.apply_along_axis(lambda x: _find_your_cluster(x, centroids),
#      40                               axis = 1,
#      41                                arr=data.as_matrix()
#
# <ipython-input-11-a96e86fac751> in _find_your_cluster(x, centroids)
#      28     distances = np.apply_along_axis(func1d=np.linalg.norm,
#      29                                    axis =1,
# ---> 30                                    arr = centroids-x)
#      31
#      32     return np.argmin(distances)
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     152     # save the first result, then compute and save all remaining results
#     153     buff[ind0] = res
# --> 154     for ind in inds:
#     155         buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     156
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/shape_base.py in <genexpr>(.0)
#     123     # prevent 0d arrays decaying to scalars, which fixes gh-8642
#     124     inds = ndindex(inarr_view.shape[:-1])
# --> 125     inds = (ind + (Ellipsis,) for ind in inds)
#     126
#     127     # invoke the function on the first item
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/index_tricks.py in __next__(self)
#     596         """
#     597         next(self._it)
# --> 598         return self._it.multi_index
#     599
#     600     next = __next__
#
# KeyboardInterrupt:

# %% [markdown]
# # sklearn KMeans

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=16, n_init=100, n_jobs=-1)

# %%
model.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=16, n_init=100, n_jobs=-1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
centroids = model.cluster_centers_
print(centroids.shape)
# Out:
# (16, 3)

# %%
C = model.predict(data)
print(C.shape)
# Out:
# (16384,)

# %%
centroids[C].shape
# Out:
# (16384, 3)

# %%
compressed_pic = centroids[C].reshape((128, 128, 3))

# %%
fig, ax = plt.subplots(1, 2)
ax[0].imshow(pic)
ax[1].imshow(compressed_pic)
plt.show()
